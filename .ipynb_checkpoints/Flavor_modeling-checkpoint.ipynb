# %% [markdown]
# # Flavor Preference: Part 2
#
# Will ask Jane about their flavor offering decisions rationale when we talk next. Some analysis in the mean time:
#
# Litres consumed per flavor might not an accurate measure of flavor preference because people had little choice in the three flavors they got to chose from at any time.
#
# Inverse time is can be a good measure of preference! If the flavor is offered, how quickly is chosen and consumed. Lets explore that here.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import warnings
warnings.filterwarnings('ignore')
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse.linalg import svds

# %matplotlib inline

# %%
#import the data that combined stations and country, and was processed in LifeSoda_analysis.ipynb
combined=pd.read_csv('data/combined_data.csv')
combined.head() #reminder
# Out:
#    amount_vended_L  flavor_id    flavor_name  tank_level_after  \
# 0              1.0          7        coconut             999.0
# 1              0.5          7        coconut             998.5
# 2              1.0         18  earl_grey_tea             997.5
# 3              1.0          7        coconut             996.5
# 4              1.0         21      blueberry             995.5
#
#              timestamp  statn   F1   F2   F3 country
# 0  2019-01-01 01:00:00      4  499  500  500     BRY
# 1  2019-01-01 01:45:00      4  498  500  500     BRY
# 2  2019-01-01 02:30:00      4  498  500  499     BRY
# 3  2019-01-01 02:56:00      4  497  500  499     BRY
# 4  2019-01-01 03:22:00      4  497  499  499     BRY

# %%
#To do: convert to function, do for F1,F2,F3 using the fxn instead of 3 separate.
#Store and import because running this takes quite long.
'''
F1=pd.DataFrame(columns=['statn','flavor','start_time','stop_time','stop_level']) #Assuming start level is always 499
j=0
for i in range(len(combined.F1)-1):
    if combined.F1[i]==499:
        F1.loc[j,'statn']=combined.statn[i]
        F1.loc[j,'start_time']=combined.timestamp[i]
    elif combined.F1[i]<combined.F1[i+1]:
        F1.loc[j,'flavor']=combined.flavor_name[i]
        F1.loc[j,'stop_level']=combined.F1[i]
        F1.loc[j,'stop_time']=combined.timestamp[i]
        j=j+1
        
F2=pd.DataFrame(columns=['statn','flavor','start_time','stop_time','stop_level']) #Assuming start level is always 499
j=0
for i in range(len(combined.F2)-1):
    if combined.F2[i]==499:
        F2.loc[j,'statn']=combined.statn[i]
        F2.loc[j,'start_time']=combined.timestamp[i]
    elif combined.F2[i]<combined.F2[i+1]:
        F2.loc[j,'flavor']=combined.flavor_name[i]
        F2.loc[j,'stop_level']=combined.F2[i]
        F2.loc[j,'stop_time']=combined.timestamp[i]
        j=j+1
        
F3=pd.DataFrame(columns=['statn','flavor','start_time','stop_time','stop_level']) #Assuming start level is always 499
j=0
for i in range(len(combined.F3)-1):
    if combined.F3[i]==499:
        F3.loc[j,'statn']=combined.statn[i]
        F3.loc[j,'start_time']=combined.timestamp[i]
    elif combined.F3[i]<combined.F3[i+1]:
        F3.loc[j,'flavor']=combined.flavor_name[i]
        F3.loc[j,'stop_level']=combined.F3[i]
        F3.loc[j,'stop_time']=combined.timestamp[i]
        j=j+1
        
flav_time = pd.concat([F1,F2,F3], ignore_index=True)
flav_time.dropna(inplace=True)
flav_time=flav_time[flav_time.flavor!='water']
flav_time.head()


flav_time.to_csv('data/flav_time.csv',index=False)
'''

# %%
flav_time = pd.read_csv('data/flav_time.csv')
flav_time.head()
# Out:
#    statn      flavor           start_time            stop_time  stop_level
# 0      4       mango  2019-01-10 06:27:00  2019-01-15 09:35:00           9
# 1      4   raspberry  2019-01-21 08:30:00  2019-01-24 15:33:00           9
# 2      4        acai  2019-01-24 15:46:00  2019-01-30 22:09:00           9
# 3      4  blackberry  2019-01-30 22:35:00  2019-02-04 09:28:00           9
# 4      4  strawberry  2019-02-04 09:38:00  2019-02-11 16:40:00           9

# %%
# How many days between flavor start and end?
flav_time.start_time=pd.to_datetime(flav_time.start_time)
flav_time.stop_time=pd.to_datetime(flav_time.stop_time)
flav_time['del_time']=flav_time.stop_time-flav_time.start_time
flav_time['del_time_days']=[i/dt.timedelta(days=1) for i in flav_time.del_time]
flav_time.drop(columns=['start_time','stop_time','del_time'],inplace=True)

#For flavors that were replaced before they were cosumed down to level zero, the time is scaled proportionally
#Eg. If it took 8 days from level to go from 500 to 100, and then the flavor was replaced (level of dispenser..
#goes up to 499; replacement is another or same flavor), the time for the former flavor to go down to zero..
# would've been 10 days.

flav_time['days_norm']=[flav_time.del_time_days[i]*500/(500-flav_time.stop_level[i]) for i in range(len(flav_time))]
flav_time.head()
# Out:
#    statn      flavor  stop_level  del_time_days  days_norm
# 0      4       mango           9       5.130556   5.224598
# 1      4   raspberry           9       3.293750   3.354124
# 2      4        acai           9       6.265972   6.380827
# 3      4  blackberry           9       4.453472   4.535104
# 4      4  strawberry           9       7.293056   7.426737

# %%
#Plot days to consume flavors fully. Higher numbers cropped in the graph.
crop=flav_time.days_norm[flav_time.days_norm<90]
sns.distplot(crop,kde=False,bins=100)
plt.title('Days to consume flavors');

# %%
#Pivot table of number of days!
table = pd.pivot_table(flav_time, values='days_norm', index=['flavor'],columns=['statn'], aggfunc=np.mean)
table
# Out:
# statn                 0          1           2           3          4   \
# flavor
# acai           15.468715        NaN   14.971572         NaN  39.588811
# blackberry           NaN   8.050464   20.756926         NaN   4.339924
# blueberry      32.226655        NaN         NaN         NaN   5.071811
# cherry         27.482179        NaN   15.903068         NaN        NaN
# coconut              NaN        NaN   21.257637         NaN        NaN
# cranberry      17.081778        NaN         NaN    7.129017        NaN
# cucumber       24.164914   8.138153   10.189310         NaN   2.190824
# earl_grey_tea        NaN  14.553927         NaN  117.270710   9.666591
# eucalyptus           NaN  44.160982         NaN         NaN  14.466650
# grapefruit           NaN   9.345299         NaN         NaN   4.049276
# green_tea            NaN   6.697994    8.464160    6.818214   2.192238
# key_lime             NaN        NaN  352.700761         NaN   3.211982
# lemon                NaN   7.237921         NaN    6.935958        NaN
# lemon_lime     16.003338        NaN         NaN         NaN        NaN
# lemonade             NaN   5.985517         NaN         NaN        NaN
# lime           12.128027   6.183526         NaN    7.046631        NaN
# mackerel             NaN        NaN         NaN         NaN  56.223835
# mango                NaN   7.965603   19.642361         NaN   5.224598
# mint           24.836643  19.859921         NaN         NaN  10.374943
# oolong         21.037706        NaN         NaN    6.402396   3.465858
# orange               NaN  11.684629         NaN         NaN        NaN
# peach          25.888210        NaN   31.751740         NaN   5.838325
# pear                 NaN  14.649059         NaN    6.815385   4.562330
# pine_needle    16.932316        NaN         NaN         NaN        NaN
# pomegranate          NaN  11.957598   33.080556    7.508062   6.066135
# raspberry            NaN        NaN         NaN         NaN   2.774595
# strawberry     23.816191        NaN    9.960540    7.129017   5.911617
# tuna_fish            NaN   7.034963         NaN         NaN        NaN
#
# statn                 5           6          7            8          9   ...  \
# flavor                                                                   ...
# acai           15.192917         NaN  10.713790          NaN  17.151788  ...
# blackberry     17.436779  212.859322   5.209041    13.403768  12.417261  ...
# blueberry      32.324197    7.601393        NaN          NaN   9.531993  ...
# cherry               NaN    5.268443        NaN          NaN        NaN  ...
# coconut              NaN         NaN   5.638295    13.543788        NaN  ...
# cranberry            NaN    5.324310        NaN          NaN        NaN  ...
# cucumber       24.596007         NaN        NaN          NaN        NaN  ...
# earl_grey_tea  25.886796   25.154983        NaN          NaN  10.853700  ...
# eucalyptus           NaN   12.211784   5.415535          NaN  45.409736  ...
# grapefruit           NaN         NaN        NaN    10.761767        NaN  ...
# green_tea      20.999751         NaN   4.850504    11.254667  12.489746  ...
# key_lime             NaN    4.722505  13.999420    19.590872        NaN  ...
# lemon                NaN    7.519730        NaN          NaN        NaN  ...
# lemon_lime     24.366427         NaN   5.926822  1290.342460  16.901446  ...
# lemonade       17.920485    5.286830   5.916214          NaN        NaN  ...
# lime                 NaN    9.981808        NaN    18.281144        NaN  ...
# mackerel             NaN         NaN        NaN          NaN        NaN  ...
# mango          15.287678         NaN        NaN          NaN        NaN  ...
# mint                 NaN         NaN        NaN          NaN  17.111117  ...
# oolong               NaN   11.916935  14.448263    22.346685  20.692606  ...
# orange         26.936241         NaN        NaN    16.709804        NaN  ...
# peach                NaN    5.437104  12.934813    15.516076        NaN  ...
# pear                 NaN         NaN        NaN          NaN        NaN  ...
# pine_needle    22.666327         NaN   5.270565          NaN        NaN  ...
# pomegranate          NaN         NaN  15.007822          NaN        NaN  ...
# raspberry            NaN         NaN        NaN    15.367841        NaN  ...
# strawberry     25.909408         NaN   5.547777    13.650571  26.313377  ...
# tuna_fish            NaN   32.203270        NaN          NaN        NaN  ...
#
# statn                 40         41          42         43          44  \
# flavor
# acai                 NaN        NaN         NaN  11.360743         NaN
# blackberry      9.893358        NaN         NaN        NaN         NaN
# blueberry      20.627546        NaN         NaN        NaN   25.342979
# cherry         14.434827  23.581410         NaN  15.288385  248.250451
# coconut              NaN        NaN         NaN        NaN         NaN
# cranberry      13.512673  21.353106    7.057592        NaN         NaN
# cucumber       14.535246  18.788892         NaN  10.703807   19.470568
# earl_grey_tea  14.103870        NaN         NaN        NaN   14.520395
# eucalyptus     42.945091        NaN  111.751328  11.764265         NaN
# grapefruit           NaN  19.901022    6.358198   7.846091         NaN
# green_tea      16.305635        NaN         NaN   8.149337         NaN
# key_lime             NaN  63.253140         NaN  23.285811         NaN
# lemon           9.919524        NaN         NaN   7.046277   19.313963
# lemon_lime           NaN        NaN         NaN        NaN         NaN
# lemonade             NaN  17.220084   14.287028        NaN         NaN
# lime                 NaN  18.643189   15.788357        NaN         NaN
# mackerel             NaN        NaN         NaN        NaN         NaN
# mango           8.960125  17.351211   18.952252        NaN         NaN
# mint                 NaN        NaN         NaN  10.484777         NaN
# oolong               NaN  21.384575         NaN        NaN         NaN
# orange         10.174813        NaN   16.177777  18.817285   18.392877
# peach          24.627320  22.036820   15.405069  16.273478         NaN
# pear                 NaN        NaN    7.042034        NaN   19.825476
# pine_needle          NaN        NaN    7.317125        NaN   11.560317
# pomegranate    13.202418        NaN   25.553717        NaN   17.129865
# raspberry       7.870135        NaN    6.472760        NaN         NaN
# strawberry           NaN        NaN   16.173239  16.176194   18.875641
# tuna_fish       7.265148        NaN   57.795833        NaN         NaN
#
# statn                 45         46          47         48          49
# flavor
# acai                 NaN        NaN    9.595326  10.920881         NaN
# blackberry     14.204282        NaN    6.576714        NaN    6.811496
# blueberry      14.382496        NaN   18.120139        NaN         NaN
# cherry         15.029560        NaN         NaN        NaN    6.250707
# coconut              NaN        NaN    9.396200   5.846204         NaN
# cranberry      10.825413        NaN         NaN        NaN         NaN
# cucumber       18.255218  12.300577   16.138408        NaN  165.649682
# earl_grey_tea  23.755890  28.592597   15.692889        NaN         NaN
# eucalyptus           NaN        NaN    4.622794   7.878621         NaN
# grapefruit           NaN        NaN    6.448716   4.529093         NaN
# green_tea      14.931263        NaN    8.267566   9.428606         NaN
# key_lime       23.864750        NaN         NaN        NaN    7.263380
# lemon                NaN        NaN         NaN        NaN         NaN
# lemon_lime     14.324508   8.377885         NaN        NaN         NaN
# lemonade       13.545910        NaN    4.015685        NaN         NaN
# lime                 NaN        NaN    3.677656        NaN         NaN
# mackerel             NaN        NaN         NaN        NaN         NaN
# mango                NaN  16.605167         NaN        NaN         NaN
# mint                 NaN   8.780974         NaN        NaN   10.606886
# oolong               NaN        NaN         NaN        NaN         NaN
# orange         22.820702        NaN    4.413117        NaN    8.892354
# peach                NaN        NaN   16.310958        NaN         NaN
# pear           15.600585        NaN  234.491088        NaN    6.638238
# pine_needle          NaN   9.157191         NaN        NaN   37.932468
# pomegranate    17.506789  17.393169         NaN  12.935215    6.093007
# raspberry      13.432762        NaN    4.873840   4.543590         NaN
# strawberry           NaN  15.604492    7.830556   9.528457    6.580957
# tuna_fish            NaN        NaN    5.435336        NaN    7.301389
#
# [28 rows x 50 columns]

# %% [markdown]
# ## Speed of consumption ~ Rating
#
# Yay we have a pivot table with avg days to consume 500 units of flavor at each station. More liked a flavor, less the number of days to consume it! Each station has different rates of total consumption, so we weigh flavors by the minimum number of days taken to consume the most favorite flavor at that station, to standardize to consumption.
#
# Note, standardization usually is performed as x_standardized=(x-x_mean)/(x_max-x_min). But in this case, scaling by fastest consumed makes most sense.
# Another note, this might not work well if two favorite flavors were available at the same time. eg. Station X would've picked key_lime over pear and raspberry, but because lemonade was available, key_lime consumption was slow.
#
# Then, lets take the inverse of time to convert this to a scale of 0-5 "rating": a more familiar and intuitive scale. If necessary, we'll do 1/log(time) or 1/time^2. Starting with 1/normalized_time, and scaling 0-5 for now.

# %%
rating=pd.DataFrame()
for column in table:
    rating[column]=round(5/(table[column]/np.nanmin(table[column])),1)

# %%
cmap=sns.diverging_palette(5, 250, as_cmap=True) #light_palette("seagreen",as_cmap=True)
def magnify():
    return [dict(selector="th",
                 props=[("font-size", "5pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]
rating.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '100px', 'font-size': '4pt'})\
    .set_caption("Hover to magnify")\
    .set_precision(2)\
    .set_table_styles(magnify()).highlight_null('white')
# Out:
# <style  type="text/css" >
#     #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4 th {
#           font-size: 5pt;
#     }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4 td {
#           padding: 0em 0em;
#     }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4 th:hover {
#           font-size: 12pt;
#     }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col0 {
#             background-color:  #95b3d8;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col1 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col2 {
#             background-color:  #e8eff7;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col3 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col4 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col5 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col6 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col7 {
#             background-color:  #f7d6dd;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col8 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col9 {
#             background-color:  #e8eff7;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col10 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col11 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col12 {
#             background-color:  #dc526e;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col13 {
#             background-color:  #cbdaec;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col14 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col15 {
#             background-color:  #b3c9e3;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col16 {
#             background-color:  #efafbc;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col17 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col18 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col19 {
#             background-color:  #8faed6;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col20 {
#             background-color:  #a4bede;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col21 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col22 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col23 {
#             background-color:  #cbdaec;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col24 {
#             background-color:  #f7d6dd;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col25 {
#             background-color:  #cbdaec;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col26 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col27 {
#             background-color:  #4a7ebd;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col28 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col29 {
#             background-color:  #6993c8;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col30 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col31 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col32 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col33 {
#             background-color:  #8faed6;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_1ca205ca_c3b3_11ea_9b16_c22e8668e9d4row0_col34 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-

# %% [markdown]
# Green tea, strawberry, and lime have a lowest rating of 2, so are more broadly liked than others. But there is no flavor that everyone likes unanimously!  Perhaps certain stations have similar taste. Time to order by country! There might be some (very few) dispenser malfunctions in there too.
# cmap only seems to take 1 axis. Ideally, we'd have the same color scale across rows and columns. Can look into this later.

# %%
#Order columns (stations) by country. Remember metadata.csv?
station=pd.read_csv('data/metadata.csv')
station=station.sort_values(by=['country','id'])
rating_country=rating[station.id.to_list()]

rating_country.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '100px', 'font-size': '4pt'})\
    .set_caption("Hover to magnify")\
    .set_precision(2)\
    .set_table_styles(magnify()).highlight_null('white')
#Would be great to add country atop groups of columns
# Out:
# <style  type="text/css" >
#     #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4 th {
#           font-size: 5pt;
#     }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4 td {
#           padding: 0em 0em;
#     }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4 th:hover {
#           font-size: 12pt;
#     }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col0 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col1 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col2 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col3 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col4 {
#             background-color:  #efafbc;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col5 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col6 {
#             background-color:  #8faed6;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col7 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col8 {
#             background-color:  #8faed6;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col9 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col10 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col11 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col12 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col13 {
#             background-color:  #f7d6dd;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col14 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col15 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col16 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col17 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col18 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col19 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col20 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col21 {
#             background-color:  #cbdaec;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col22 {
#             background-color:  #cbdaec;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col23 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col24 {
#             background-color:  #6993c8;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col25 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col26 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col27 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col28 {
#             background-color:  #f1b8c3;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col29 {
#             background-color:  #f4c8d0;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col30 {
#             background-color:  #e8eff7;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col31 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col32 {
#             background-color:  #e8eff7;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_391cbe3a_c3b3_11ea_9118_c22e8668e9d4row0_col33 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             background-color:  white;
#         }    #T_391cbe3a_c3b3_11ea_9118_

# %% [markdown]
# Adjacent columns should've looked similar, but don't really. Hmm. Well, a simplistic way to tell the 3 most liked flavor at any station is to find top 3 with highest scores (fastest consumed) at that station. Lets start with that, and we can come back to cross-station or flavor correlations later.

# %%
fav_three=pd.DataFrame(columns=['fav_winner','fav_rup1','fav_rup2'])
for col in rating:
    fav_three.loc[len(fav_three)]=rating.nlargest(3,[col]).index.to_list()
    
#print(fav_three.fav_winner.mode())
fav_three.head() #rup:Runner_up!
# Out:
#   fav_winner   fav_rup1    fav_rup2
# 0       lime       acai  lemon_lime
# 1   lemonade       lime   green_tea
# 2  green_tea   cucumber  strawberry
# 3     oolong  green_tea        pear
# 4   cucumber  green_tea   raspberry

# %%
flat=rating.values.flatten()
sns.distplot(flat,kde=False,bins=20)
plt.xlabel('Rating');
plt.ylabel('Count');

# %% [markdown]
# This is not very typical of ratings data, especially the peak near 5. It happened because we set the most popular flavor at each station to rating 5.

# %% [markdown]
# ## Correlations
#
# Since stations from the same country were placed next to each other, we expected to see a larger blue region around the daigonal than we do. Flavor preferences seem to vary significantly. Lets see next if flavors have correlation.
#
# Number close to 1 (blue) indicates "folks who liked flavor x also liked flavor y", -1 (red) indicates "folks who loved flavor x really disliked flavor y", and 0 (near white) indicates "there isn't really much relation. folks who like x may or may not like y.

# %%
rating_country.corr(method='spearman').style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '100px', 'font-size': '4pt'})\
    .set_caption("Hover to magnify")\
    .set_precision(2)\
    .set_table_styles(magnify()).highlight_null('white')
# Out:
# <style  type="text/css" >
#     #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4 th {
#           font-size: 5pt;
#     }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4 td {
#           padding: 0em 0em;
#     }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4 th:hover {
#           font-size: 12pt;
#     }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col0 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col1 {
#             background-color:  #f6d3da;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col2 {
#             background-color:  #f7d7de;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col3 {
#             background-color:  #eb9bab;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col4 {
#             background-color:  #ecf2f8;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col5 {
#             background-color:  #efafbc;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col6 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col7 {
#             background-color:  #eb9ead;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col8 {
#             background-color:  #e88d9f;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col9 {
#             background-color:  #dce6f2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col10 {
#             background-color:  #e57f93;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col11 {
#             background-color:  #7099cb;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col12 {
#             background-color:  #aec5e1;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col13 {
#             background-color:  #9bb7da;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col14 {
#             background-color:  #e7899c;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col15 {
#             background-color:  #f7d7de;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col16 {
#             background-color:  #7da2cf;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col17 {
#             background-color:  #cfddee;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col18 {
#             background-color:  #f4cad3;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col19 {
#             background-color:  #bccfe7;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col20 {
#             background-color:  #f3c4cd;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col21 {
#             background-color:  #eda6b4;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col22 {
#             background-color:  #eaf0f7;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col23 {
#             background-color:  #e16d85;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col24 {
#             background-color:  #f8dce2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col25 {
#             background-color:  #e78a9d;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col26 {
#             background-color:  #ebf1f8;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col27 {
#             background-color:  #f7d6dd;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col28 {
#             background-color:  #f8dee3;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col29 {
#             background-color:  #acc3e1;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col30 {
#             background-color:  #cfddee;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col31 {
#             background-color:  #5787c2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col32 {
#             background-color:  #cfddee;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col33 {
#             background-color:  #efb1be;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col34 {
#             background-color:  #5787c2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col35 {
#             background-color:  #e2eaf4;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_9f05f3dc_c3bc_11ea_95bb_c22e8668e9d4row0_col

# %%
rating_country.transpose().corr().style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '100px', 'font-size': '4pt'})\
    .set_caption("Hover to magnify")\
    .set_precision(2)\
    .set_table_styles(magnify()).highlight_null('white')
# Out:
# <style  type="text/css" >
#     #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4 th {
#           font-size: 5pt;
#     }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4 td {
#           padding: 0em 0em;
#     }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4 th:hover {
#           font-size: 12pt;
#     }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col0 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col1 {
#             background-color:  #d1deee;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col3 {
#             background-color:  #e4ecf5;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col4 {
#             background-color:  #eeaebb;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col5 {
#             background-color:  #f1bcc7;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col6 {
#             background-color:  #f3c2cc;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col7 {
#             background-color:  #bfd1e8;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col8 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col9 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col10 {
#             background-color:  #e4798e;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col11 {
#             background-color:  #d73d5c;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col12 {
#             background-color:  #e16981;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col13 {
#             background-color:  #e3788d;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col14 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col15 {
#             background-color:  #eb9dac;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col16 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col17 {
#             background-color:  #d5e1f0;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col18 {
#             background-color:  #d5e1f0;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col19 {
#             background-color:  #f3c6cf;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col20 {
#             background-color:  #f7d9df;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col21 {
#             background-color:  #dfe8f3;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col22 {
#             background-color:  #bbcee6;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col23 {
#             background-color:  #e4798e;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col24 {
#             background-color:  #e7879b;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col25 {
#             background-color:  #de5b75;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col26 {
#             background-color:  #f9e3e7;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row0_col27 {
#             background-color:  #8dadd5;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row1_col0 {
#             background-color:  #e2eaf4;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row1_col1 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row1_col2 {
#             background-color:  #ebf1f8;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row1_col3 {
#             background-color:  #e58094;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row1_col4 {
#             background-color:  #b1c7e2;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row1_col5 {
#             background-color:  #da4966;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row1_col6 {
#             background-color:  #eb9dac;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row1_col7 {
#             background-color:  #c3d4e9;
#             color:  #000000;
#             max-width:  100px;
#             font-size:  4pt;
#             : ;
#         }    #T_d6f59024_c3b4_11ea_8517_c22e8668e9d4row1_col8 {

# %% [markdown]
# Folks who like lemon despise key_lime, are indifferent towards lemon_lime and lime, but love lemonade. This doesn't make much sense. We should revisit our construct of Rating metric. There is a chance that data doesn't follow intuition, but we should try other rating constructs before settling there. Given limited time, lets first finish coding some recommender systems, and everything can be easily rerun with new rating definition.

# %% [markdown]
# ## Future Work:
# I'd explore:
#
# 1. Cosine similarity because Angular distance is a better measure of rating similarity than Eucleadian distance! Cosine similarity can't handle NaN, so we pad missing data with mean. Note this assumption.
# 2. SVD (Matrix factorization) used in collaborative recommender systems.
# 3. K Nearest Neighbors

# %% [markdown]
# ## Local flavor preferences and plan
#
# With the analysis we have so far, we can test 3 flavors from the most similar station, and use that data to analyse performance against current top 3 at that station (in fav_three above). Since preferences vary a lot across stations, this is a better option than considering all stations' votes towards a flavor profile.
